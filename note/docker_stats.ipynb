# %%
import pandas as pd

# %%
df = pd.read_csv("docker_stats.csv")
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')

# %%
df
# Out:
#               Timestamp     Container                        Name  \
# 0   2025-02-27 02:11:52  82683638170d       reverse-proxy-cache-1
# 1   2025-02-27 02:11:52  d0e094025c73       reverse-proxy-agent-1
# 2   2025-02-27 02:11:52  9947d69af862          reverse-proxy-lb-1
# 3   2025-02-27 02:11:52  ebc59ece3ba0  reverse-proxy-controller-1
# 4   2025-02-27 02:11:52  4b208a6a1dea         reverse-proxy-api-1
# ..                  ...           ...                         ...
# 101 2025-02-27 02:21:43  6314788638ac       reverse-proxy-cache-1
# 102 2025-02-27 02:21:43  af762eb3befa          reverse-proxy-lb-1
# 103 2025-02-27 02:21:43  ed298524516e       reverse-proxy-agent-1
# 104 2025-02-27 02:21:43  0d143fae543e  reverse-proxy-controller-1
# 105 2025-02-27 02:21:43  ac343d2d2902         reverse-proxy-api-1
#
#                ID CPUPerc             MemUsage MemPerc            NetIO  \
# 0    82683638170d   0.00%     17.27MiB / 20MiB  86.33%    132MB / 126MB
# ...
